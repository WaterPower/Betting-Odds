# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import shapiro, normaltest, anderson, probplot

# Load the CSV data
data = pd.read_csv('result_NN.csv')

# Calculate the difference between 'Theoretical%' and '%OF WIN'
data['Difference'] = data['Theoretical%'] - data['%OF WIN']

# Perform normality tests
shapiro_test = shapiro(data['Difference'])

# Print the test results
print(f"Shapiro-Wilk Test: Statistic={shapiro_test.statistic}, p-value={shapiro_test.pvalue}")

# Visualize the distribution of the differences using a histogram
plt.figure(figsize=(12, 6))
sns.histplot(data['Difference'], kde=True)
plt.title('Histogram of difference between Implied probability and Real win probability')
plt.xlabel('Difference')
plt.ylabel('Frequency')
plt.show()
# Out:
# Shapiro-Wilk Test: Statistic=0.9921011192941683, p-value=0.8720167083052983

# %%
import pandas as pd
from scipy import stats

# Assuming your data is in a CSV file named 'data.csv'
df = pd.read_csv('result_NN.csv')

# Perform the paired t-test
t_stat, p_value = stats.ttest_ind(df['Theoretical%'], df['%OF WIN'])

# Print the results
print("Paired T-statistic:", t_stat)
print("Paired P-value:", p_value)
# Out:
# Paired T-statistic: 0.4444881404373379
# Paired P-value: 0.6572296563740363

# %%
import pandas as pd
from scipy import stats

# Assuming your data is in a CSV file named 'data.csv'
df = pd.read_csv('result.csv')

# Perform the paired t-test
t_stat, p_value = stats.ttest_ind(df['Theoretical%'], df['%OF WIN'])

# Print the results
print("Paired T-statistic:", t_stat)
print("Paired P-value:", p_value)
# Out:
# Paired T-statistic: 0.00830715140522178
# Paired P-value: 0.9933815555975678
